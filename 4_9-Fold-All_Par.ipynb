# %% [markdown]
# # IMPORT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time
import math

# %% [markdown]
# # METHOD

# %% [markdown]
# ### Euclidean Distance(For Numpy Array)

# %%
def eu_distance(e1,e2):
    return math.sqrt(math.fsum(list(map(lambda x: x**2 ,e1-e2))))

# %% [markdown]
# ### Generate Data and Results for each File

# %%
def read_all_lines(file) :
    with open(file, 'rt') as fd:
        convert = [e.split() for e in fd.readlines()]
        all_data = []
        all_results = []
        for line in convert:
            data = line
            result = data.pop(-1)
            all_data.append(data)
            all_results.append(result)
            
        float_data = []
        for element in all_data:
            float_data.append([float(e) for e in element])
        float_data = np.array(float_data)
        all_results = np.array(all_results)
        
        normalized_data = []
        for element in float_data:
            mean = math.fsum(element)/len(element)
            std = math.sqrt(sum((element-mean)**2)/(len(element)-1))
            normalized_data.append((element - mean)/std)
        normalized_data = np.array(normalized_data)
        return normalized_data, all_results

# %% [markdown]
# ### Dynamic Time Warping

# %%
def dtw_distance(s1, s2):
    DTW={}

    for i in range(len(s1)):
        DTW[(i, -1)] = float('inf')
    for i in range(len(s2)):
        DTW[(-1, i)] = float('inf')
    DTW[(-1, -1)] = 0

    for i in range(len(s1)):
        for j in range(len(s2)):
            dist= (s1[i]-s2[j])**2
            DTW[(i, j)] = dist + min(DTW[(i-1, j)],DTW[(i, j-1)], DTW[(i-1, j-1)])

    return np.sqrt(DTW[len(s1)-1, len(s2)-1])

# %% [markdown]
# ### DBA

# %%
from __future__ import division
from functools import reduce


__author__ ="Francois Petitjean"

def performDBA(series, n_iterations=30):
    n_series = len(series)
    max_length = reduce(max, map(len, series))

    cost_mat = np.zeros((max_length, max_length))
    delta_mat = np.zeros((max_length, max_length))
    path_mat = np.zeros((max_length, max_length), dtype=np.int8)

    medoid_ind = approximate_medoid_index(series,cost_mat,delta_mat)
    center = series[medoid_ind]

    for i in range(0,n_iterations):
        center = DBA_update(center, series, cost_mat, path_mat, delta_mat)

    return center

def approximate_medoid_index(series,cost_mat,delta_mat):
    if len(series)<=50:
        indices = range(0,len(series))
    else:
        indices = np.random.choice(range(0,len(series)),50,replace=False)

    medoid_ind = -1
    best_ss = 1e20
    for index_candidate in indices:
        candidate = series[index_candidate]
        ss = sum_of_squares(candidate,series,cost_mat,delta_mat)
        if(medoid_ind==-1 or ss<best_ss):
            best_ss = ss
            medoid_ind = index_candidate
    return medoid_ind

def sum_of_squares(s,series,cost_mat,delta_mat):
    return sum(map(lambda t:squared_DTW(s,t,cost_mat,delta_mat),series))

def DTW(s,t,cost_mat,delta_mat):
    return np.sqrt(squared_DTW(s,t,cost_mat,delta_mat))

def squared_DTW(s,t,cost_mat,delta_mat):
    s_len = len(s)
    t_len = len(t)
    length = len(s)
    fill_delta_mat_dtw(s, t, delta_mat)
    cost_mat[0, 0] = delta_mat[0, 0]
    for i in range(1, s_len):
        cost_mat[i, 0] = cost_mat[i-1, 0]+delta_mat[i, 0]

    for j in range(1, t_len):
        cost_mat[0, j] = cost_mat[0, j-1]+delta_mat[0, j]

    for i in range(1, s_len):
        for j in range(1, t_len):
            diag,left,top =cost_mat[i-1, j-1], cost_mat[i, j-1], cost_mat[i-1, j]
            if(diag <=left):
                if(diag<=top):
                    res = diag
                else:
                    res = top
            else:
                if(left<=top):
                    res = left
                else:
                    res = top
            cost_mat[i, j] = res+delta_mat[i, j]
    return cost_mat[s_len-1,t_len-1]

def fill_delta_mat_dtw(center, s, delta_mat):
    slim = delta_mat[:len(center),:len(s)]
    np.subtract.outer(center, s,out=slim)
    np.square(slim, out=slim)

def DBA_update(center, series, cost_mat, path_mat, delta_mat):
    options_argmin = [(-1, -1), (0, -1), (-1, 0)]
    updated_center = np.zeros(center.shape)
    n_elements = np.array(np.zeros(center.shape), dtype=int)
    center_length = len(center)
    for s in series:
        s_len = len(s)
        fill_delta_mat_dtw(center, s, delta_mat)
        cost_mat[0, 0] = delta_mat[0, 0]
        path_mat[0, 0] = -1

        for i in range(1, center_length):
            cost_mat[i, 0] = cost_mat[i-1, 0]+delta_mat[i, 0]
            path_mat[i, 0] = 2

        for j in range(1, s_len):
            cost_mat[0, j] = cost_mat[0, j-1]+delta_mat[0, j]
            path_mat[0, j] = 1

        for i in range(1, center_length):
            for j in range(1, s_len):
                diag,left,top =cost_mat[i-1, j-1], cost_mat[i, j-1], cost_mat[i-1, j]
                if(diag <=left):
                    if(diag<=top):
                        res = diag
                        path_mat[i,j] = 0
                    else:
                        res = top
                        path_mat[i,j] = 2
                else:
                    if(left<=top):
                        res = left
                        path_mat[i,j] = 1
                    else:
                        res = top
                        path_mat[i,j] = 2

                cost_mat[i, j] = res+delta_mat[i, j]

        i = center_length-1
        j = s_len-1

        while(path_mat[i, j] != -1):
            updated_center[i] += s[j]
            n_elements[i] += 1
            move = options_argmin[path_mat[i, j]]
            i += move[0]
            j += move[1]
        assert(i == 0 and j == 0)
        updated_center[i] += s[j]
        n_elements[i] += 1

    return np.divide(updated_center, n_elements)

# %% [markdown]
# ### SubClassSplitting

# %%
def subClassSplitting(mrcp_data,noise_data,mrcp_results,noise_results,threshold):
    sum_mrcp_list = list()
    for each_mrcp_data in mrcp_data:
        sum_mrcp_list.append(math.fsum(each_mrcp_data))
    avg_mrcp = float(math.fsum(sum_mrcp_list)/len(mrcp_data))

    sum_noise_list = list()
    for each_noise_data in noise_data:
        sum_noise_list.append(math.fsum(each_noise_data))
    avg_noise = float(math.fsum(sum_noise_list)/len(noise_data))

#         print('Avg_MRCP: ', avg_mrcp, '\nAvg_Noise: ', avg_noise)

    mrcp_pivot = -1
    mrcp_min = float('inf')
    for i in range(len(sum_mrcp_list)):
        abs_subs = abs(sum_mrcp_list[i] - avg_mrcp)
        if  abs_subs < mrcp_min :
            mrcp_pivot = i
            mrcp_min = abs_subs

    noise_pivot = -1
    noise_min = float('inf')
    for i in range(len(sum_noise_list)):
        abs_subs = abs(sum_noise_list[i] - avg_noise)
        if  abs_subs < noise_min :
            noise_pivot = i
            noise_min = abs_subs

#         print('MRCP_pivot: ', mrcp_pivot, '\nNoise_pivot: ', noise_pivot)

    #MRCP-------------------------------------------------------------------------------------------------

    dist = []
    for each_mrcp_data,idx in zip(mrcp_data,range(len(mrcp_data))):
        dist.append([eu_distance(each_mrcp_data,mrcp_data[mrcp_pivot]),idx])

    sorted_dist = sorted(dist,key=lambda x:x[0])
#         print('Sorted_Dist_MRCP: ',sorted_dist[:3])

    diff = []
    for i in range(1,len(sorted_dist)):
        diff.append(sorted_dist[i][0]-sorted_dist[i-1][0]);
    diff = np.array(diff)
#         print('Diff_MRCP: ',diff[:3])

    T_mean = math.fsum(diff)/len(diff)
    T_std = math.sqrt(math.fsum((diff-T_mean)**2)/(len(diff)-1)) 
    T = T_std/2
#         print('T_MRCP: ',T)

    Class = []
    temp_c = []
    temp_c.append(sorted_dist[0][1])
    for i in range(len(diff)):
        if(diff[i] > T):
            Class.append(temp_c)
            temp_c = []
            temp_c.append(sorted_dist[i+1][1])
        else:
            temp_c.append(sorted_dist[i+1][1])

    selected_mrcp_class = list()
    removed_mrcp_class = list()
    for e in Class:
        if len(e)>threshold: selected_mrcp_class.append(e)
        else: removed_mrcp_class.append(e)

    mrcp_avg = []
    for i in range(len(selected_mrcp_class)):
        l = []
        for e in selected_mrcp_class[i]:
            l.append(mrcp_data[e])
        mrcp_avg.append(performDBA(l))

    l = list()
    for i in range(len(removed_mrcp_class)):
        for e in removed_mrcp_class[i]:
            l.append(e)
    l = np.array(l)
    filtered_mrcp_data = np.delete(mrcp_data,l,axis=0)

    #Noise-------------------------------------------------------------------------------------------------

    dist = []
    for each_noise_data,idx in zip(noise_data,range(len(noise_data))):
        dist.append([eu_distance(each_noise_data,noise_data[noise_pivot]),idx])

    sorted_dist = sorted(dist,key=lambda x:x[0])
#         print('Sorted_Dist_Noise: ',sorted_dist[:3])

    diff = []
    for i in range(1,len(sorted_dist)):
        diff.append(sorted_dist[i][0]-sorted_dist[i-1][0]);
    diff = np.array(diff)
#         print('Diff_Noise: ',diff[:3])

    T_mean = math.fsum(diff)/len(diff)
    T_std = math.sqrt(math.fsum((diff-T_mean)**2)/(len(diff)-1)) 
    T = T_std/2
#         print('T_Noise: ',T)

    Class = []
    temp_c = []
    temp_c.append(sorted_dist[0][1])
    for i in range(len(diff)):
        if(diff[i] > T):
            Class.append(temp_c)
            temp_c = []
            temp_c.append(sorted_dist[i+1][1])
        else:
            temp_c.append(sorted_dist[i+1][1])

    selected_noise_class = list()
    removed_noise_class = list()
    for e in Class:
        if len(e)>threshold: selected_noise_class.append(e)
        else: removed_noise_class.append(e)

    noise_avg = []
    for i in range(len(selected_noise_class)):
        l = []
        for e in selected_noise_class[i]:
            l.append(noise_data[e])
        noise_avg.append(performDBA(l))

    l = list()
    for i in range(len(removed_noise_class)):
        for e in removed_noise_class[i]:
            l.append(e)
    l = np.array(l)
    filtered_noise_data = np.delete(noise_data,l,axis=0)
    
    return mrcp_avg,noise_avg,len(mrcp_avg),len(noise_avg)

# %% [markdown]
# ### Calculate F1 Score

# %%
def score_eu(test_data,test_results,mrcp_avg,noise_avg):
    e_results = list()
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for each_test_data in test_data:
        e_class = None
        min_dist = float('inf')
        for avg in mrcp_avg:
            dist = eu_distance(each_test_data, avg) 
            if dist < min_dist:
                min_dist = dist
                e_class = 'MRCP'
        for avg in noise_avg:
            dist = eu_distance(each_test_data, avg) 
            if dist < min_dist:
                min_dist = dist
                e_class = 'Noise'
        e_results.append(e_class)
    e_results = np.array(e_results)
    for i in range(len(test_data)):
        if e_results[i] == 'MRCP' and test_results[i] == 'MRCP' :
            TP += 1
        elif e_results[i] == 'MRCP' and test_results[i] == 'Noise' :
            FP += 1
        elif e_results[i] == 'Noise' and test_results[i] == 'MRCP' :
            FN += 1
        elif e_results[i] == 'Noise' and test_results[i] == 'Noise' :
            TN += 1
    return TP,FP,FN,TN

def score_dtw(test_data,test_results,mrcp_avg,noise_avg):
    e_results = list()
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for each_test_data in test_data:
        e_class = None
        min_dist = float('inf')
        for avg in mrcp_avg:
            dist = dtw_distance(each_test_data, avg) 
            if dist < min_dist:
                min_dist = dist
                e_class = 'MRCP'
        for avg in noise_avg:
            dist = dtw_distance(each_test_data, avg) 
            if dist < min_dist:
                min_dist = dist
                e_class = 'Noise'
        e_results.append(e_class)
    e_results = np.array(e_results)
    for i in range(len(test_data)):
        if e_results[i] == 'MRCP' and test_results[i] == 'MRCP' :
            TP += 1
        elif e_results[i] == 'MRCP' and test_results[i] == 'Noise' :
            FP += 1
        elif e_results[i] == 'Noise' and test_results[i] == 'MRCP' :
            FN += 1
        elif e_results[i] == 'Noise' and test_results[i] == 'Noise' :
            TN += 1
    return TP,FP,FN,TN

def cal_f1(TP,FP,FN,TN):
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    accuracy = (TP+TN)/(TP+TN+FP+FN)*100
    f1_score = (2*precision*recall)/(precision+recall)*100
    return f1_score

# %% [markdown]
# # IMPORT DATA

# %% [markdown]
# ### Generate Data and Results for each File

# %%
start_time = time.time()
print('***************************************(( 9 Participants with 1-NN ))***************************************')
TP = 0
TN = 0
FP = 0
FN = 0
for par in range(1,10):
    all_data = np.empty((0,41))
    all_results = np.empty((0,1))
    train_num = []
    for i in range(1,10):
        if i == par:
            test_data , test_results = read_all_lines('all data/participant_'+str(i)+'.txt')
            test_num = i
            continue
        train_num.append(i)
        data , results = read_all_lines('all data/participant_'+str(i)+'.txt')
        all_data = np.vstack([all_data,data])
        all_results = np.vstack([all_results,results.reshape(len(results),1)])

    mrcp_data = list()
    noise_data = list()
    mrcp_result = list()
    noise_result = list()

    for each_data, each_result in zip(all_data,all_results):
        if each_result == 'MRCP':
            mrcp_data.append(each_data)
            mrcp_result.append(each_result)
        else:
            noise_data.append(each_data)
            noise_result.append(each_result)

    mrcp_data = np.array(mrcp_data)
    noise_data = np.array(noise_data)
    mrcp_results = np.array(mrcp_result)
    noise_results = np.array(noise_result)

    temp_TP,temp_FP,temp_FN,temp_TN = score_dtw(test_data,test_results,mrcp_data,noise_data)
    TP += temp_TP
    FP += temp_FP
    FN += temp_FN
    TN += temp_TN
    print('Test:',test_num,'Train:',train_num,'are success!')

    print('TP:', TP, ',FP:', FP, ',FN:', FN, ',TN:', TN)
    f1_score = cal_f1(TP,FP,FN,TN)
    print('F1_Score:',f1_score)
    print('----------------------------------------------')

print('----------------------------------------------------------------------------------------------------')
elapsed_time = time.time() - start_time
print("Took {} hours".format(elapsed_time/3600))
# Out:
# ***************************************(( 9 Participants with 1-NN ))***************************************
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# TP: 140 ,FP: 77 ,FN: 44 ,TN: 86
# F1_Score: 69.82543640897757
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# TP: 271 ,FP: 209 ,FN: 94 ,TN: 124
# F1_Score: 64.14201183431953
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# TP: 409 ,FP: 244 ,FN: 143 ,TN: 249
# F1_Score: 67.88381742738589
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# TP: 522 ,FP: 313 ,FN: 208 ,TN: 348
# F1_Score: 66.70926517571884
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# TP: 653 ,FP: 354 ,FN: 252 ,TN: 463
# F1_Score: 68.30543933054393
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# TP: 757 ,FP: 409 ,FN: 298 ,TN: 544
# F1_Score: 68.16749212066637
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# TP: 882 ,FP: 478 ,FN: 387 ,TN: 679
# F1_Score: 67.09775580068468
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# TP: 1023 ,FP: 544 ,FN: 457 ,TN: 817
# F1_Score: 67.14801444043322
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# TP: 1140 ,FP: 604 ,FN: 534 ,TN: 940
# F1_Score: 66.70567583382095
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Took 7.467511978215642 hours

# %%
start_time = time.time()
print('***************************************(( 9 Participants with SubClassSpltting ))***************************************')
for threshold in range(0,15,2):
    print('( Threshold: {} )'.format(threshold))
    for par in range(1,10):
        TP = 0
        TN = 0
        FP = 0
        FN = 0
        all_data = np.empty((0,41))
        all_results = np.empty((0,1))
        train_num = []
        for i in range(1,10):
            if i == par:
                test_data , test_results = read_all_lines('all data/participant_'+str(i)+'.txt')
                test_num = i
                continue
            train_num.append(i)
            data , results = read_all_lines('all data/participant_'+str(i)+'.txt')
            all_data = np.vstack([all_data,data])
            all_results = np.vstack([all_results,results.reshape(len(results),1)])
        
        mrcp_data = list()
        noise_data = list()
        mrcp_result = list()
        noise_result = list()

        for each_data, each_result in zip(all_data,all_results):
            if each_result == 'MRCP':
                mrcp_data.append(each_data)
                mrcp_result.append(each_result)
            else:
                noise_data.append(each_data)
                noise_result.append(each_result)

        mrcp_data = np.array(mrcp_data)
        noise_data = np.array(noise_data)
        mrcp_results = np.array(mrcp_result)
        noise_results = np.array(noise_result)

        mrcp_avg,noise_avg,no_mrcp_class,no_noise_class = subClassSplitting(mrcp_data,noise_data,mrcp_results,noise_results,threshold)

        TP,FP,FN,TN = score_dtw(test_data,test_results,mrcp_avg,noise_avg)
        
        print('Test:',test_num,'Train:',train_num,'are success!')
        print('Number of MRCP Class:',no_mrcp_class,',','Number of Noise Class:',no_noise_class)
        print('TP:', TP, ',FP:', FP, ',FN:', FN, ',TN:', TN)
        f1_score = cal_f1(TP,FP,FN,TN)
        print('F1_Score:',f1_score)
        print('----------------------------------------------')
    
    print('----------------------------------------------------------------------------------------------------')
elapsed_time = time.time() - start_time
print("Took {} hours".format(elapsed_time/3600))
# Out:
# ***************************************(( 9 Participants with SubClassSpltting ))***************************************
# ( Threshold: 0 )
# C:\Users\Suphattarawanich.Top\Anaconda3\lib\site-packages\ipykernel_launcher.py:81: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
# C:\Users\Suphattarawanich.Top\Anaconda3\lib\site-packages\ipykernel_launcher.py:132: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 181 , Number of Noise Class: 73
# TP: 156 ,FP: 117 ,FN: 28 ,TN: 46
# F1_Score: 68.27133479212254
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 187 , Number of Noise Class: 469
# TP: 92 ,FP: 105 ,FN: 89 ,TN: 65
# F1_Score: 48.67724867724868
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 24 , Number of Noise Class: 87
# TP: 48 ,FP: 6 ,FN: 139 ,TN: 154
# F1_Score: 39.83402489626556
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 68 , Number of Noise Class: 180
# TP: 44 ,FP: 32 ,FN: 134 ,TN: 136
# F1_Score: 34.645669291338585
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# Number of MRCP Class: 165 , Number of Noise Class: 91
# TP: 142 ,FP: 120 ,FN: 33 ,TN: 36
# F1_Score: 64.98855835240275
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# Number of MRCP Class: 83 , Number of Noise Class: 497
# TP: 44 ,FP: 23 ,FN: 106 ,TN: 113
# F1_Score: 40.55299539170507
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# Number of MRCP Class: 71 , Number of Noise Class: 345
# TP: 53 ,FP: 23 ,FN: 161 ,TN: 181
# F1_Score: 36.55172413793103
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# Number of MRCP Class: 66 , Number of Noise Class: 29
# TP: 167 ,FP: 145 ,FN: 44 ,TN: 59
# F1_Score: 63.862332695984705
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# Number of MRCP Class: 70 , Number of Noise Class: 23
# TP: 158 ,FP: 121 ,FN: 36 ,TN: 62
# F1_Score: 66.8076109936575
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ( Threshold: 2 )
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 115 , Number of Noise Class: 39
# TP: 152 ,FP: 109 ,FN: 32 ,TN: 54
# F1_Score: 68.31460674157303
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 122 , Number of Noise Class: 167
# TP: 111 ,FP: 154 ,FN: 70 ,TN: 16
# F1_Score: 49.77578475336323
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 11 , Number of Noise Class: 57
# TP: 60 ,FP: 9 ,FN: 127 ,TN: 151
# F1_Score: 46.875
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 50 , Number of Noise Class: 108
# TP: 54 ,FP: 52 ,FN: 124 ,TN: 116
# F1_Score: 38.028169014084504
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# Number of MRCP Class: 105 , Number of Noise Class: 57
# TP: 149 ,FP: 117 ,FN: 26 ,TN: 39
# F1_Score: 67.57369614512471
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# Number of MRCP Class: 60 , Number of Noise Class: 186
# TP: 68 ,FP: 43 ,FN: 82 ,TN: 93
# F1_Score: 52.10727969348659
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# Number of MRCP Class: 49 , Number of Noise Class: 175
# TP: 60 ,FP: 25 ,FN: 154 ,TN: 179
# F1_Score: 40.13377926421405
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# Number of MRCP Class: 51 , Number of Noise Class: 19
# TP: 162 ,FP: 135 ,FN: 49 ,TN: 69
# F1_Score: 63.77952755905512
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# Number of MRCP Class: 51 , Number of Noise Class: 12
# TP: 163 ,FP: 112 ,FN: 31 ,TN: 71
# F1_Score: 69.5095948827292
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ( Threshold: 4 )
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 88 , Number of Noise Class: 31
# TP: 152 ,FP: 106 ,FN: 32 ,TN: 57
# F1_Score: 68.77828054298642
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 78 , Number of Noise Class: 77
# TP: 129 ,FP: 66 ,FN: 52 ,TN: 104
# F1_Score: 68.61702127659575
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 7 , Number of Noise Class: 40
# TP: 74 ,FP: 12 ,FN: 113 ,TN: 148
# F1_Score: 54.21245421245421
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 43 , Number of Noise Class: 77
# TP: 62 ,FP: 56 ,FN: 116 ,TN: 112
# F1_Score: 41.891891891891895
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# Number of MRCP Class: 83 , Number of Noise Class: 39
# TP: 151 ,FP: 111 ,FN: 24 ,TN: 45
# F1_Score: 69.10755148741418
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# Number of MRCP Class: 55 , Number of Noise Class: 83
# TP: 82 ,FP: 55 ,FN: 68 ,TN: 81
# F1_Score: 57.14285714285713
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# Number of MRCP Class: 44 , Number of Noise Class: 101
# TP: 88 ,FP: 43 ,FN: 126 ,TN: 161
# F1_Score: 51.01449275362319
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# Number of MRCP Class: 45 , Number of Noise Class: 16
# TP: 161 ,FP: 154 ,FN: 50 ,TN: 50
# F1_Score: 61.2167300380228
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# Number of MRCP Class: 42 , Number of Noise Class: 9
# TP: 168 ,FP: 124 ,FN: 26 ,TN: 59
# F1_Score: 69.1358024691358
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ( Threshold: 6 )
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 71 , Number of Noise Class: 26
# TP: 150 ,FP: 103 ,FN: 34 ,TN: 60
# F1_Score: 68.64988558352402
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 55 , Number of Noise Class: 47
# TP: 130 ,FP: 66 ,FN: 51 ,TN: 104
# F1_Score: 68.96551724137932
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 5 , Number of Noise Class: 25
# TP: 83 ,FP: 9 ,FN: 104 ,TN: 151
# F1_Score: 59.498207885304666
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 34 , Number of Noise Class: 56
# TP: 66 ,FP: 59 ,FN: 112 ,TN: 109
# F1_Score: 43.56435643564357
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# Number of MRCP Class: 66 , Number of Noise Class: 27
# TP: 151 ,FP: 113 ,FN: 24 ,TN: 43
# F1_Score: 68.79271070615034
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# Number of MRCP Class: 50 , Number of Noise Class: 45
# TP: 89 ,FP: 60 ,FN: 61 ,TN: 76
# F1_Score: 59.53177257525084
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# Number of MRCP Class: 36 , Number of Noise Class: 54
# TP: 108 ,FP: 55 ,FN: 106 ,TN: 149
# F1_Score: 57.29442970822281
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# Number of MRCP Class: 37 , Number of Noise Class: 15
# TP: 159 ,FP: 146 ,FN: 52 ,TN: 58
# F1_Score: 61.62790697674419
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# Number of MRCP Class: 35 , Number of Noise Class: 6
# TP: 161 ,FP: 127 ,FN: 33 ,TN: 56
# F1_Score: 66.80497925311202
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ( Threshold: 8 )
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 49 , Number of Noise Class: 24
# TP: 146 ,FP: 101 ,FN: 38 ,TN: 62
# F1_Score: 67.74941995359629
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 43 , Number of Noise Class: 30
# TP: 150 ,FP: 122 ,FN: 31 ,TN: 48
# F1_Score: 66.22516556291392
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 3 , Number of Noise Class: 23
# TP: 73 ,FP: 17 ,FN: 114 ,TN: 143
# F1_Score: 52.707581227436826
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 29 , Number of Noise Class: 39
# TP: 62 ,FP: 54 ,FN: 116 ,TN: 114
# F1_Score: 42.176870748299315
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# Number of MRCP Class: 51 , Number of Noise Class: 25
# TP: 151 ,FP: 104 ,FN: 24 ,TN: 52
# F1_Score: 70.23255813953489
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# Number of MRCP Class: 42 , Number of Noise Class: 26
# TP: 93 ,FP: 65 ,FN: 57 ,TN: 71
# F1_Score: 60.38961038961038
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# Number of MRCP Class: 30 , Number of Noise Class: 33
# TP: 118 ,FP: 71 ,FN: 96 ,TN: 133
# F1_Score: 58.56079404466501
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# Number of MRCP Class: 31 , Number of Noise Class: 15
# TP: 146 ,FP: 112 ,FN: 65 ,TN: 92
# F1_Score: 62.26012793176972
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# Number of MRCP Class: 29 , Number of Noise Class: 6
# TP: 158 ,FP: 93 ,FN: 36 ,TN: 90
# F1_Score: 71.01123595505616
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ( Threshold: 10 )
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 44 , Number of Noise Class: 21
# TP: 148 ,FP: 106 ,FN: 36 ,TN: 57
# F1_Score: 67.57990867579909
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 37 , Number of Noise Class: 16
# TP: 157 ,FP: 122 ,FN: 24 ,TN: 48
# F1_Score: 68.26086956521739
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 3 , Number of Noise Class: 20
# TP: 86 ,FP: 14 ,FN: 101 ,TN: 146
# F1_Score: 59.93031358885018
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 26 , Number of Noise Class: 32
# TP: 62 ,FP: 59 ,FN: 116 ,TN: 109
# F1_Score: 41.47157190635451
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# Number of MRCP Class: 46 , Number of Noise Class: 19
# TP: 154 ,FP: 100 ,FN: 21 ,TN: 56
# F1_Score: 71.7948717948718
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# Number of MRCP Class: 32 , Number of Noise Class: 13
# TP: 121 ,FP: 78 ,FN: 29 ,TN: 58
# F1_Score: 69.34097421203438
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# Number of MRCP Class: 26 , Number of Noise Class: 19
# TP: 132 ,FP: 88 ,FN: 82 ,TN: 116
# F1_Score: 60.829493087557594
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# Number of MRCP Class: 30 , Number of Noise Class: 14
# TP: 155 ,FP: 105 ,FN: 56 ,TN: 99
# F1_Score: 65.81740976645435
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# Number of MRCP Class: 23 , Number of Noise Class: 6
# TP: 155 ,FP: 80 ,FN: 39 ,TN: 103
# F1_Score: 72.26107226107227
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ( Threshold: 12 )
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 33 , Number of Noise Class: 15
# TP: 146 ,FP: 109 ,FN: 38 ,TN: 54
# F1_Score: 66.51480637813212
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 26 , Number of Noise Class: 12
# TP: 156 ,FP: 122 ,FN: 25 ,TN: 48
# F1_Score: 67.97385620915031
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 2 , Number of Noise Class: 19
# TP: 70 ,FP: 19 ,FN: 117 ,TN: 141
# F1_Score: 50.72463768115942
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 22 , Number of Noise Class: 27
# TP: 66 ,FP: 60 ,FN: 112 ,TN: 108
# F1_Score: 43.42105263157895
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# Number of MRCP Class: 38 , Number of Noise Class: 16
# TP: 151 ,FP: 103 ,FN: 24 ,TN: 53
# F1_Score: 70.39627039627041
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# Number of MRCP Class: 24 , Number of Noise Class: 10
# TP: 110 ,FP: 74 ,FN: 40 ,TN: 62
# F1_Score: 65.86826347305389
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# Number of MRCP Class: 22 , Number of Noise Class: 14
# TP: 127 ,FP: 82 ,FN: 87 ,TN: 122
# F1_Score: 60.047281323877066
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# Number of MRCP Class: 24 , Number of Noise Class: 13
# TP: 146 ,FP: 107 ,FN: 65 ,TN: 97
# F1_Score: 62.93103448275862
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# Number of MRCP Class: 20 , Number of Noise Class: 6
# TP: 154 ,FP: 84 ,FN: 40 ,TN: 99
# F1_Score: 71.29629629629629
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ( Threshold: 14 )
# Test: 1 Train: [2, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 32 , Number of Noise Class: 13
# TP: 146 ,FP: 109 ,FN: 38 ,TN: 54
# F1_Score: 66.51480637813212
# ----------------------------------------------
# Test: 2 Train: [1, 3, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 19 , Number of Noise Class: 8
# TP: 153 ,FP: 121 ,FN: 28 ,TN: 49
# F1_Score: 67.25274725274726
# ----------------------------------------------
# Test: 3 Train: [1, 2, 4, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 2 , Number of Noise Class: 16
# TP: 66 ,FP: 14 ,FN: 121 ,TN: 146
# F1_Score: 49.438202247191015
# ----------------------------------------------
# Test: 4 Train: [1, 2, 3, 5, 6, 7, 8, 9] are success!
# Number of MRCP Class: 19 , Number of Noise Class: 19
# TP: 68 ,FP: 61 ,FN: 110 ,TN: 107
# F1_Score: 44.299674267100976
# ----------------------------------------------
# Test: 5 Train: [1, 2, 3, 4, 6, 7, 8, 9] are success!
# Number of MRCP Class: 29 , Number of Noise Class: 11
# TP: 150 ,FP: 103 ,FN: 25 ,TN: 53
# F1_Score: 70.09345794392523
# ----------------------------------------------
# Test: 6 Train: [1, 2, 3, 4, 5, 7, 8, 9] are success!
# Number of MRCP Class: 23 , Number of Noise Class: 4
# TP: 141 ,FP: 90 ,FN: 9 ,TN: 46
# F1_Score: 74.01574803149606
# ----------------------------------------------
# Test: 7 Train: [1, 2, 3, 4, 5, 6, 8, 9] are success!
# Number of MRCP Class: 20 , Number of Noise Class: 12
# TP: 125 ,FP: 81 ,FN: 89 ,TN: 123
# F1_Score: 59.523809523809526
# ----------------------------------------------
# Test: 8 Train: [1, 2, 3, 4, 5, 6, 7, 9] are success!
# Number of MRCP Class: 20 , Number of Noise Class: 12
# TP: 144 ,FP: 97 ,FN: 67 ,TN: 107
# F1_Score: 63.71681415929204
# ----------------------------------------------
# Test: 9 Train: [1, 2, 3, 4, 5, 6, 7, 8] are success!
# Number of MRCP Class: 19 , Number of Noise Class: 6
# TP: 153 ,FP: 79 ,FN: 41 ,TN: 104
# F1_Score: 71.83098591549295
# ----------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Took 6.843677813079622 hours
